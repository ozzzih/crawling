# %%
# !pip install wget
# Out:
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9673 sha256=ffaa143fe1b5e6aecc38a513004d0a0eeab22634f51e03ee9353e5207915b8ce
#   Stored in directory: c:\users\오 지현\appdata\local\pip\cache\wheels\bd\a8\c3\3cf2c14a1837a4e04bd98631724e81f33f462d86a1d895fae0
# Successfully built wget
# ...
# WARNING: Ignoring invalid distribution -pype1 (c:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\anaconda\lib\site-packages)
# WARNING: Ignoring invalid distribution -pype1 (c:\anaconda\lib\site-packages)
# WARNING: You are using pip version 21.1.2; however, version 22.1.2 is available.
# ...

# %%
import wget
url = 'https://bitbucket.org/eunjeon/mecab-ko/downloads/mecab-0.996-ko-0.9.2.tar.gz'
wget.download(url)
# Out:
# 100% [..........................................................................] 1414979 / 1414979
# 'mecab-0.996-ko-0.9.2.tar.gz'

# %%
import tarfile
tar tarfile

# %%
from nltk.tokenize import word_tokenize
from konlpy.tag import Kkma; kkma=Kkma()
from konlpy.tag import Hannanum; hannanum = Hannanum()
from konlpy.tag import Okt; t=Okt()
from konlpy.tag import *
from konlpy.tag import Mecab

# %%
from konlpy.tag import Komoran

# %%
import os

# %%
os.chdir('C:\\anaconda\\Lib\\site-packages\\konlpy\\java\\aaa')
os.getcwd()
# Out:
# 'C:\\anaconda\\Lib\\site-packages\\konlpy\\java\\aaa'

# %%
with open(f'\\anaconda\\Lib\\site-packages\\konlpy\\java\\aaa\\org\\openkoreantext\\processor\\util\\noun\\names.txt',"rt",encoding="UTF8") as f:
    data = f.read()

# %%
data
# Out:
# '가몽\n가온\n갓세븐\n강새이\n게임닉가\n관우\n귀여미\n규\n김유이\n김준면\n까까런\n노컷\n누너예\n니노\n다마고치\n다이무스\n대학생\n데이브\n도요토미\n동운\n동이\n두주니\n디시인사이드\n디오\n라몹\n라스\n라옵\n멍구\n메이든\n명덕\n명량\n문민정부\n미네\n방엘리\n병헌\n붓다\n비정상회담\n빼빼로\n삼풍\n샤인온미\n성식\n성열\n세라문\n세라복\n세종대왕\n손권\n손책\n쇼미더머니\n쇼챔\n순규\n스라소니\n신동아\n신쓰패밀리\n신아라\n아베\n안상홍\n안홍준\n여누\n여랑\n여포\n연합\n오꾸닭\n요섭\n웃찾사\n원식\n유병언\n유비\n유이\n윤기형\n이나단\n이명박\n이완용\n임창용\n자괴\n자니윤\n자대련\n자유\n재중이\n전교조\n정윤회\n제갈량\n조자룡\n조조\n준면\n지오디\n지존파\n진영오\n차작가\n차트\n창섭\n챠트\n첸\n코르사주\n하무열\n하용파쿠\n혁재\n현이\n현태\n혜미\n'

# %%
data += '엘페이\n엘포인트\n엘포켓\n롯데온\n캐시백\n'

# %%
with open('\\anaconda\\Lib\\site-packages\\konlpy\\java\\aaa\\org\\openkoreantext\\processor\\util\\noun\\names.txt',"w") as f:
    f.write(data)

# %%
# !jar cvf ../openkorean-text-2.1.0.jar *
# Out:
# 'jar'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.

# %%
from konlpy.tag import Okt
okt=Okt()

# %%
print(okt.nouns('엘페이'))
# Out:
# ['엘', '페이']

# %%
import pandas as pd
data = pd.read_excel('naver_blog_content.xlsx')
# Out:
# C:\anaconda\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Conditional Formatting extension is not supported and will be removed
#   warn(msg)

# %%
df = data.astype({'title': str})
list_df=df['title'].values.tolist()

# %%
list_df
# Out:
# ["['\\n            일룸 땅콩800책상 78257원(엘페이삼성카드)\\n        ']",
#  "['\\n            엘페이 프리미엄 3개월 가입하세요~ 엘포인트\\n        ']",
#  "['\\n            엘페이 적립관련 질문이요!\\n        ']",
#  "['\\n            롯데싸다구 엘페이결제 -L포인트 천포인트^^\\n        ']",
#  "['\\n            씨유 엘페이 결제, 멤버십 적립 질문\\n        ']",
#  "['\\n            엘페이,앱카드가 뭔가요??\\n        ']",
#  "['\\n            더모아 결재시 신한플레이-간편결재-엘페이?\\n        ']",
#  "['\\n            네스프레소 가격 인상 롯데롤라카드 엘페이20프로 적립\\n        ']",
#  "['\\n            배민 더모아결제 엘페이,일반결제 더블적립문의해요\\n        ']",
#  "['\\n            엘페이 프리미엄 백화점 사용되나요?\\n        ']",
#  "['\\n            엘페이 첫 구매에 대한 질문입니다.\\n        ']",
#  "['\\n            짭모아 카드 (신한카카오뱅크카드) 쓰시는분. 엘페이 결제하시나요\\n        ']",
#  "['\\n            롯데온 추가적립정보(앱에서 엘페이 구매한정)\\n        ']",
#  "['\\n            엘페이 엘포켓\\n        ']",
#  "['\\n            [롯데온] 세이펜 태극펜64G+세이맵+아기똥낱말카드157장+분리형충전기 핫딜 118,440원(삼성) 119,450원(롯데, 우리)+엘페이 5,000P 적립\\n        ']",
# ...

# %%
#morph_list=[]
#for i in list_df:
#    morphs=t.morphs(i)
#    for morph in morphs:
#        morph_list.append(morph)

# %%
morph_list=[]
for i in list_df:
    morph_list.append(t.morphs(i))

# %%
komoran_userdic.nouns(list_df[0])
# Out:
# ['일', '룸', '땅콩', '800', '책상', '원', '엘', '페이', '삼성카드']

# %%
#불용어 처리
stop_words = ['?\\','+','n',"['\\",'\\',')',')\\','시','?','1','"(', '_', ')/','\n','.',',', '<','!','(','(', '??','..', '4', '|', '>', '?(', '"…', '#', '&', '・', "']",'.',' ','/',"'",'’','”','“','·', '[','!','\n','·','‘','"','\n ',']',':','…',')','(','-', 'nan','가','요','답변','...','을','수','에','질문','제','를','이','도',
                      '좋','1','는','로','으로','2','것','은','다',',','니다','대','들',
              '이다','하고','입니다','대한','에서','수사','심의',
                      '2017','들','데','..','의','때','겠','고','게','네요','한','일','할',
                      '10','?','하는','06','주','려고','인데','거','좀','는데','~','ㅎㅎ',
                      '하나','이상','20','뭐','까','있는','잘','습니다','다면','했','주려',
                      '지','있','못','후','중','줄','6','과','어떤','기본','!!',
                      '단어','라고','중요한','합','가요','....','보이','네','무지',
             '적', '성', '삼', '등', '전', '인', '그', '했다', '와', '위', '해', '권', '된', '서', '말', '분']

# %%
morph_list
# Out:
# [<bound method Komoran.nouns of <konlpy.tag._komoran.Komoran object at 0x00000196D90CD9D0>>,
#  <bound method Komoran.nouns of <konlpy.tag._komoran.Komoran object at 0x00000196D90CD9D0>>,
#  <bound method Komoran.nouns of <konlpy.tag._komoran.Komoran object at 0x00000196D90CD9D0>>,
#  <bound method Komoran.nouns of <konlpy.tag._komoran.Komoran object at 0x00000196D90CD9D0>>,
#  <bound method Komoran.nouns of <konlpy.tag._komoran.Komoran object at 0x00000196D90CD9D0>>,
#  <bound method Komoran.nouns of <konlpy.tag._komoran.Komoran object at 0x00000196D90CD9D0>>,
#  <bound method Komoran.nouns of <konlpy.tag._komoran.Komoran object at 0x00000196D90CD9D0>>,
#  <bound method Komoran.nouns of <konlpy.tag._komoran.Komoran object at 0x00000196D90CD9D0>>,
#  <bound method Komoran.nouns of <konlpy.tag._komoran.Komoran object at 0x00000196D90CD9D0>>,
#  <bound method Komoran.nouns of <konlpy.tag._komoran.Komoran object at 0x00000196D90CD9D0>>,
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-5d51458fc16c> in <module>
# ----> 1 print(komoran_userdic.nouns(list_df))
#
# C:\anaconda\lib\site-packages\konlpy\tag\_komoran.py in nouns(self, phrase)
#      81         """Noun extractor."""
#      82
# ---> 83         tagged = self.pos(phrase)
#      84         return [s for s, t in tagged if t.startswith('NN')]
#      85
#
# C:\anaconda\lib\site-packages\konlpy\tag\_komoran.py in pos(self, phrase, flatten, join)
#      58         """
#      59
# ---> 60         sentences = phrase.split('\n')
#      61         morphemes = []
#      62         if not sentences:
#
# AttributeError: 'list' object has no attribute 'split'

# %%
import pickle
import nltk
morph_list = [each_word for each_word in morph_list
             if each_word not in stop_words]

ko = nltk.Text(morph_list)
ko.vocab().most_common(10)
# Out:
# [('엘', 241),
#  ('페이', 207),
#  ('롯데', 92),
#  ('결제', 92),
#  ('포인트', 74),
#  ('카드', 48),
#  ('적립', 42),
#  ('할인', 35),
#  ('하이마트', 33),
#  ('포켓', 29)]

# %%
morph_list
# Out:
# ['일룸',
#  '땅콩',
#  '800',
#  '책상',
#  '78257원',
#  '엘',
#  '페이',
#  '삼성',
#  '카드',
#  '엘',
#  '페이',
#  '프리미엄',
#  '3',
#  '개월',
#  '가입',
#  '하세요',
#  '엘',
#  '포인트',
#  '엘',
#  '페이',
#  '적립',
#  '관련',
#  '!\\',
#  '롯데',
#  '싸다구',
#  '엘',
#  '페이',
#  '결제',
#  'L',
#  '포인트',
#  '천',
#  '포인트',
#  '^^\\',
#  '씨유',
#  '엘',
#  '페이',
#  '결제',
#  '멤버십',
#  '적립',
#  '엘',
#  '페이',
#  '앱',
#  '카드',
#  '뭔가',
#  '??\\',
#  '더',
#  '모아',
#  '결재',
#  '신한',
#  '플레이',
#  '간편',
#  '결재',
#  '엘',
#  '페이',
#  '네스프레소',
#  '가격',
#  '인상',
#  '롯데',
#  '롤라',
#  '카드',
#  '엘',
#  '페이',
#  '프로',
#  '적립',
#  '배민',
#  '더',
#  '모아',
#  '결제',
#  '엘',
#  '페이',
#  '일반',
#  '결제',
#  '더블',
#  '적립',
#  '문의',
#  '엘',
#  '페이',
#  '프리미엄',
#  '백화점',
#  '사용',
#  '되나요',
#  '엘',
#  '페이',
#  '첫',
#  '구매',
#  '.\\',
#  '짭',
#  '모아',
#  '카드',
#  '신',
#  '카카오',
#  '뱅크',
#  '카드',
#  '쓰시',
#  '엘',
#  '페이',
#  '결제',
#  '하시나요',
#  '롯데',
#  '온',
#  '추가',
#  '적립',
#  '정보',
#  '앱',
#  '엘',
#  '페이',
#  '구매',
#  '한정',
#  '엘',
#  '페이',
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

from collections import Counter
plt.figure(figsize=(15,10))

plt.title("엘페이 키워드")
plt.xticks(rotation=-45)
ko.plot(5)
plt.show()

# %%
import numpy as np
import pandas as pd
import re
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from konlpy.tag import Hannanum
hannanum = Hannanum()

# %%
dataset=[]
for i in range(len(list_df)):
    dataset.append(hannanum.nouns(re.sub('[^가-힣a-zA-Z\s]','',list_df[i])))

# %%
from apyori import apriori
result=(list(apriori(dataset, min_support=0.01)))
data=pd.DataFrame(result)
data['length']=data['items'].apply(lambda x: len(x))
data = data[(data['length']==2) &
           (data['support']>=0.01)].sort_values(by='support', ascending=False)

# %%
data.head(10)
# Out:
#          items   support                                 ordered_statistics  \
# 54    (엘페, 결제)  0.028630  [((), (엘페, 결제), 0.028629856850715747, 1.0), ((...
# 65     (원, 원n)  0.016360  [((), (원, 원n), 0.016359918200409, 1.0), ((원), ...
# 57    (만원, 한달)  0.014315  [((), (만원, 한달), 0.014314928425357873, 1.0), ((...
# 59     (엘페, 원)  0.014315  [((), (엘페, 원), 0.014314928425357873, 1.0), ((엘...
# 58   (엘페, 엘포켓)  0.012270  [((), (엘페, 엘포켓), 0.012269938650306749, 1.0), (...
# 63   (엘페, 포인트)  0.012270  [((), (엘페, 포인트), 0.012269938650306749, 1.0), (...
# 55   (당첨n, 엘페)  0.010225  [((), (당첨n, 엘페), 0.010224948875255624, 1.0), (...
# 56  (당첨n, 포인트)  0.010225  [((), (당첨n, 포인트), 0.010224948875255624, 1.0), ...
# 60     (엘페, 월)  0.010225  [((), (엘페, 월), 0.010224948875255624, 1.0), ((엘...
# 61    (적립, 엘페)  0.010225  [((), (적립, 엘페), 0.010224948875255624, 1.0), ((...
#
#     length
# 54       2
# 65       2
# 57       2
# 59       2
# 58       2
# 63       2
# 55       2
# 56       2
# 60       2
# ...

# %%
G = nx.Graph()
ar = (data['items']); G.add_edges_from(ar)

# %%
pr=nx.pagerank(G)
nsize = np.array([v for v in pr.values()])
nsize = 2000 * (nsize - min(nsize)) / (max(nsize) - min(nsize))

# %%
pos = nx.planar_layout(G)

# %%
plt.rcParams['font.family'] = 'NanumGothic'

# %%
# %matplotlib inline
plt.rcParams['axes.unicode_minus']=False
plt.figure(figsize=(16,12)); plt.axis('off')
nx.draw_networkx(G,font_family='NanumGothic',  font_size=16,
                pos=pos, node_color=list(pr.values()), node_size=nsize,
                alpha=0.7, edge_color='.5', cmap=plt.cm.YlGn)
